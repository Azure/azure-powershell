# %%
import os
import pandas as pd
import re

# %% [markdown]
# ### Find all modules

# %%
src_folder = os.getcwd()  
modules = [f.name for f in os.scandir(src_folder) if f.is_dir() and not f.name.startswith('.')]

# %%
len(modules)
# Out:
# 190

# %%
data = []
for module in modules:
    sub_modules = [f.name for f in os.scandir(module) if f.is_dir() and f.name.endswith('.Autorest')]
    print(f"module: {module} - sub_module: {",".join(sub_modules)}")
    if sub_modules:
        for sub_module in sub_modules:
            data.append((module,sub_module))
    else:
        data.append((module, None))
# Out:
# module: Accounts - sub_module:
# module: ADDomainServices - sub_module: ADDomainServices.Autorest
# module: Advisor - sub_module: Advisor.Autorest
# module: Aks - sub_module: Aks.Autorest
# module: AksArc - sub_module: AksArc.Autorest
# module: Alb - sub_module: Alb.Autorest
# module: AlertsManagement - sub_module: PrometheusRuleGroups.Autorest
# module: AnalysisServices - sub_module:
# module: ApiManagement - sub_module:
# module: App - sub_module: App.Autorest
# module: AppComplianceAutomation - sub_module: AppComplianceAutomation.Autorest
# module: AppConfiguration - sub_module: AppConfiguration.Autorest,AppConfigurationData.Autorest
# module: ApplicationInsights - sub_module: ApplicationInsights.Autorest
# module: ArcGateway - sub_module: ArcGateway.Autorest
# module: ArcResourceBridge - sub_module: ArcResourceBridge.Autorest
# module: Astro - sub_module: Astro.Autorest
# module: Attestation - sub_module: Attestation.Autorest
# module: Automanage - sub_module: Automanage.Autorest
# module: Automation - sub_module:
# module: BareMetal - sub_module: BareMetal.Autorest
# module: Batch - sub_module:
# module: Billing - sub_module:
# module: BillingBenefits - sub_module: BillingBenefits.Autorest
# module: Blueprint - sub_module:
# module: BotService - sub_module: BotService.Autorest
# module: Cdn - sub_module: Cdn.Autorest
# module: ChangeAnalysis - sub_module: ChangeAnalysis.Autorest
# module: Chaos - sub_module: Chaos.Autorest
# module: CloudService - sub_module: CloudService.Autorest
# module: CodeSigning - sub_module:
# module: CognitiveServices - sub_module:
# module: Communication - sub_module: Communication.Autorest,EmailService.Autorest,EmailServicedata.Autorest
# module: Compute - sub_module: Compute.Autorest
# module: ComputeFleet - sub_module: ComputeFleet.Autorest
# module: ComputeSchedule - sub_module:
# module: ConfidentialLedger - sub_module: ConfidentialLedger.Autorest
# module: Confluent - sub_module: Confluent.Autorest
# module: ConnectedKubernetes - sub_module: ConnectedKubernetes.Autorest
# module: ConnectedMachine - sub_module: ConnectedMachine.Autorest
# module: ConnectedNetwork - sub_module: ConnectedNetwork.Autorest
# module: ConnectedVMware - sub_module: ConnectedVMware.Autorest
# module: ContainerInstance - sub_module: ContainerInstance.Autorest
# module: ContainerRegistry - sub_module: ContainerRegistry.Autorest
# module: CosmosDB - sub_module:
# module: CostManagement - sub_module: CostManagement.Autorest
# module: CustomLocation - sub_module: CustomLocation.Autorest
# module: CustomProviders - sub_module: CustomProviders.Autorest
# module: Dashboard - sub_module: Dashboard.Autorest
# module: DataBox - sub_module: DataBox.Autorest
# module: DataBoxEdge - sub_module:
# module: Databricks - sub_module: Databricks.Autorest
# module: Datadog - sub_module: Datadog.Autorest
# module: DataFactory - sub_module:
# module: DataLakeAnalytics - sub_module:
# module: DataLakeStore - sub_module:
# module: DataMigration - sub_module: DataMigration.Autorest
# module: DataProtection - sub_module: DataProtection.Autorest
# module: DataShare - sub_module:
# module: DedicatedHsm - sub_module: DedicatedHsm.Autorest
# module: DesktopVirtualization - sub_module: DesktopVirtualization.Autorest
# module: DevCenter - sub_module:
# module: DeviceProvisioningServices - sub_module:
# module: DeviceRegistry - sub_module: DeviceRegistry.Autorest
# module: DeviceUpdate - sub_module: DeviceUpdate.Autorest
# module: DevTestLabs - sub_module:
# module: DigitalTwins - sub_module: DigitalTwins.Autorest
# module: DiskPool - sub_module: DiskPool.Autorest
# module: Dns - sub_module: Dns.Autorest
# module: DnsResolver - sub_module: DnsResolver.Autorest
# module: DynatraceObservability - sub_module: DynatraceObservability.Autorest
# module: EdgeOrder - sub_module: EdgeOrder.Autorest
# module: EdgeZones - sub_module: EdgeZones.Autorest
# module: Elastic - sub_module: Elastic.Autorest
# module: ElasticSan - sub_module: ElasticSan.Autorest
# module: EventGrid - sub_module: EventGrid.Autorest
# module: EventHub - sub_module: EventHub.Autorest
# module: Fabric - sub_module: Fabric.Autorest
# module: FirmwareAnalysis - sub_module: FirmwareAnalysis.Autorest
# module: Fleet - sub_module: Fleet.Autorest
# module: FluidRelay - sub_module: FluidRelay.Autorest
# module: FrontDoor - sub_module:
# module: Functions - sub_module: Functions.Autorest
# module: GraphServices - sub_module: GraphServices.Autorest
# module: GuestConfiguration - sub_module: GuestConfiguration.Autorest
# module: HanaOnAzure - sub_module: HanaOnAzure.Autorest
# module: HDInsight - sub_module:
# module: HdInsightOnAks - sub_module: HdInsightOnAks.Autorest
# module: HealthBot - sub_module: HealthBot.Autorest
# module: HealthcareApis - sub_module: HealthcareApis.Autorest
# module: HealthDataAIServices - sub_module: HealthDataAIServices.Autorest
# module: helpers - sub_module:
# module: HPCCache - sub_module:
# module: ImageBuilder - sub_module: ImageBuilder.Autorest
# module: ImportExport - sub_module: ImportExport.Autorest
# module: Informatica - sub_module: Informatica.Autorest
# module: IotCentral - sub_module:
# module: IotHub - sub_module:
# module: KeyVault - sub_module: KeyVault.Autorest
# module: KubernetesConfiguration - sub_module: KubernetesConfiguration.Autorest
# module: KubernetesRuntime - sub_module: KubernetesRuntime.Autorest
# module: Kusto - sub_module: Kusto.Autorest
# module: LabServices - sub_module: LabServices.Autorest
# module: lib - sub_module:
# module: LoadTesting - sub_module: LoadTesting.Autorest
# module: LogicApp - sub_module:
# module: MachineLearning - sub_module:
# module: MachineLearningServices - sub_module: MachineLearningServices.Autorest
# module: Maintenance - sub_module:
# module: ManagedNetworkFabric - sub_module: ManagedNetworkFabric.Autorest
# module: ManagedServiceIdentity - sub_module: ManagedServiceIdentity.Autorest
# module: ManagedServices - sub_module: ManagedServices.Autorest
# module: ManagementPartner - sub_module:
# module: Maps - sub_module: Maps.Autorest
# module: MariaDb - sub_module: MariaDb.Autorest
# module: Marketplace - sub_module: Marketplace.Autorest
# module: MarketplaceOrdering - sub_module: MarketplaceOrdering.Autorest
# module: Mdp - sub_module: Mdp.Autorest
# module: Media - sub_module:
# module: Migrate - sub_module: Migrate.Autorest
# module: MixedReality - sub_module: MixedReality.Autorest
# module: MobileNetwork - sub_module: MobileNetwork.Autorest
# module: Monitor - sub_module: ActionGroup.Autorest,ActivityLogAlert.Autorest,Autoscale.Autorest,DataCollectionRule.Autorest,DiagnosticSetting.Autorest,MetricData.Autorest,MonitorWorkspace.Autorest,PipelineGroup.Autorest,ScheduledQueryRule.Autorest
# module: MonitoringSolutions - sub_module: MonitoringSolutions.Autorest
# module: MySql - sub_module: MySql.Autorest
# module: NeonPostgres - sub_module: NeonPostgres.Autorest
# module: NetAppFiles - sub_module:
# module: Network - sub_module:
# module: NetworkAnalytics - sub_module: NetworkAnalytics.Autorest
# module: NetworkCloud - sub_module: NetworkCloud.Autorest
# module: NetworkFunction - sub_module: NetworkFunction.Autorest
# module: NewRelic - sub_module: NewRelic.Autorest
# module: Nginx - sub_module: Nginx.Autorest
# module: NotificationHubs - sub_module:
# module: OperationalInsights - sub_module:
# module: Oracle - sub_module: Oracle.Autorest
# module: Orbital - sub_module: Orbital.Autorest
# module: PaloAltoNetworks - sub_module: PaloAltoNetworks.Autorest
# module: Peering - sub_module: Peering.Autorest
# module: PolicyInsights - sub_module:
# module: Portal - sub_module: Portal.Autorest
# module: PostgreSql - sub_module: PostgreSql.Autorest
# module: PowerBIEmbedded - sub_module:
# module: PrivateDns - sub_module:
# module: ProviderHub - sub_module: ProviderHub.Autorest
# module: Purview - sub_module: Purview.Autorest,Purviewdata.Autorest
# module: Quantum - sub_module: Quantum.Autorest
# module: Qumulo - sub_module: Qumulo.Autorest
# module: Quota - sub_module: Quota.Autorest
# module: RecoveryServices - sub_module:
# module: RedisCache - sub_module:
# module: RedisEnterpriseCache - sub_module: RedisEnterpriseCache.Autorest
# module: Relay - sub_module: Relay.Autorest
# module: Reservations - sub_module: Reservations.Autorest
# module: ResourceGraph - sub_module: ResourceGraph.Autorest
# module: ResourceMover - sub_module: ResourceMover.Autorest
# module: Resources - sub_module: Authorization.Autorest,DataBoundary.Autorest,MSGraph.Autorest,Policy.Autorest
# module: Search - sub_module:
# module: Security - sub_module: DefenderForStorage.Autorest,Security.Autorest
# module: SecurityInsights - sub_module: SecurityInsights.Autorest
# module: SelfHelp - sub_module: SelfHelp.Autorest
# module: ServiceBus - sub_module: ServiceBus.Autorest
# module: ServiceFabric - sub_module:
# module: ServiceLinker - sub_module: ServiceLinker.Autorest
# module: shared - sub_module:
# module: SignalR - sub_module: SignalR.Autorest
# module: Sphere - sub_module: Sphere.Autorest
# module: SpringCloud - sub_module: SpringCloud.Autorest
# module: Sql - sub_module:
# module: SqlVirtualMachine - sub_module: SqlVirtualMachine.Autorest
# module: Ssh - sub_module:
# module: StackHCI - sub_module: StackHCI.Autorest
# module: StackHCIVM - sub_module: StackHCIVM.Autorest
# module: StandbyPool - sub_module: StandbyPool.Autorest
# module: Storage - sub_module: Storage.Autorest
# module: StorageAction - sub_module: StorageAction.Autorest
# module: StorageCache - sub_module: StorageCache.Autorest
# module: StorageMover - sub_module: StorageMover.Autorest
# module: StorageSync - sub_module:
# module: StreamAnalytics - sub_module: StreamAnalytics.Autorest
# module: Subscription - sub_module: Subscription.Autorest
# module: Support - sub_module: Support.Autorest
# module: Synapse - sub_module: Synapse.Autorest
# module: Terraform - sub_module: Terraform.Autorest
# module: TimeSeriesInsights - sub_module: TimeSeriesInsights.Autorest
# module: TrafficManager - sub_module:
# module: VMware - sub_module: VMware.Autorest
# module: VoiceServices - sub_module: VoiceServices.Autorest
# module: Websites - sub_module: Websites.Autorest
# module: WindowsIotServices - sub_module: WindowsIotServices.Autorest
# module: Workloads - sub_module: Monitors.Autorest,SapVirtualInstance.Autorest

# %%
df = pd.DataFrame(data, columns=["module", "sub_module"])
df.head()
# Out:
#              module                 sub_module
# 0          Accounts                       None
# 1  ADDomainServices  ADDomainServices.Autorest
# 2           Advisor           Advisor.Autorest
# 3               Aks               Aks.Autorest
# 4            AksArc            AksArc.Autorest

# %%
df["v_autorest"] = "v4"
df["GA"] = False
df["Status"] = None
df.head()
# Out:
#              module                 sub_module v_autorest     GA Status
# 0          Accounts                       None         v4  False   None
# 1  ADDomainServices  ADDomainServices.Autorest         v4  False   None
# 2           Advisor           Advisor.Autorest         v4  False   None
# 3               Aks               Aks.Autorest         v4  False   None
# 4            AksArc            AksArc.Autorest         v4  False   None

# %% [markdown]
# ### Find autorest version

# %%
for index, row in df.iterrows():
    if row["sub_module"] == None:
        df.at[index, "v_autorest"] = None
        continue
        
    current_dir = os.getcwd() 
    readme_path = os.path.join(current_dir, row["module"], row["sub_module"], "README.md")

    if not os.path.exists(readme_path):
        raise FileNotFoundError(f"The readme file for module: {row["module"]} sub_module： {row["sub_module"]} does not exist.")

    with open(readme_path, 'r', encoding='utf-8') as file:
        content = file.read()

        pattern = r'use-extension:\s*"\@autorest/powershell":\s*"3.x"'
        match = re.search(pattern, content, re.MULTILINE)

        if match:
            # print(f"V3 tag found in module: {row["module"]} sub_module： {row["sub_module"]}")
            df.at[index, "v_autorest"] = "v3"

# %%
df.head()
# Out:
#              module                 sub_module v_autorest     GA Status
# 0          Accounts                       None       None  False   None
# 1  ADDomainServices  ADDomainServices.Autorest         v3  False   None
# 2           Advisor           Advisor.Autorest         v3  False   None
# 3               Aks               Aks.Autorest         v3  False   None
# 4            AksArc            AksArc.Autorest         v4  False   None

# %%
df.loc[df['v_autorest'] == 'v3'].shape
# Out:
# (106, 5)

# %% [markdown]
# ### Find GA modules

# %%
pattern = r"ModuleName\s*=\s*'([^']+)';\s*RequiredVersion\s*=\s*'([^']+)'"

def extract_modules_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            match = re.search(pattern, line)
            if match:
                module_name = match.group(1).replace('Az.', '')
                required_version = match.group(2)
                print(f"ModuleName: {module_name}, RequiredVersion: {required_version}")
                
                df.loc[df['module'] == module_name, 'GA'] = True

current_dir = os.getcwd()
file_path = os.path.join(current_dir, "..", "tools/Az/Az.psd1")

extract_modules_from_file(file_path)
# Out:
# ModuleName: Advisor, RequiredVersion: 2.1.0
# ModuleName: Aks, RequiredVersion: 6.1.0
# ModuleName: AnalysisServices, RequiredVersion: 1.2.0
# ModuleName: ApiManagement, RequiredVersion: 4.1.0
# ModuleName: App, RequiredVersion: 2.0.1
# ModuleName: AppConfiguration, RequiredVersion: 1.4.0
# ModuleName: ApplicationInsights, RequiredVersion: 2.3.0
# ModuleName: ArcResourceBridge, RequiredVersion: 1.1.0
# ModuleName: Attestation, RequiredVersion: 2.1.0
# ModuleName: Automanage, RequiredVersion: 1.1.0
# ModuleName: Automation, RequiredVersion: 1.11.1
# ModuleName: Batch, RequiredVersion: 3.7.0
# ModuleName: Billing, RequiredVersion: 2.2.0
# ModuleName: Cdn, RequiredVersion: 3.3.0
# ModuleName: CloudService, RequiredVersion: 2.1.0
# ModuleName: CognitiveServices, RequiredVersion: 1.15.0
# ModuleName: Compute, RequiredVersion: 9.1.0
# ModuleName: ConfidentialLedger, RequiredVersion: 1.1.0
# ModuleName: ConnectedMachine, RequiredVersion: 1.1.1
# ModuleName: ContainerInstance, RequiredVersion: 4.1.1
# ModuleName: ContainerRegistry, RequiredVersion: 4.3.0
# ModuleName: CosmosDB, RequiredVersion: 1.17.0
# ModuleName: DataBoxEdge, RequiredVersion: 1.2.1
# ModuleName: Databricks, RequiredVersion: 1.10.0
# ModuleName: DataFactory, RequiredVersion: 1.19.1
# ModuleName: DataLakeAnalytics, RequiredVersion: 1.1.0
# ModuleName: DataLakeStore, RequiredVersion: 1.4.0
# ModuleName: DataProtection, RequiredVersion: 2.6.1
# ModuleName: DataShare, RequiredVersion: 1.1.1
# ModuleName: DesktopVirtualization, RequiredVersion: 5.4.1
# ModuleName: DevCenter, RequiredVersion: 2.0.1
# ModuleName: DevTestLabs, RequiredVersion: 1.1.0
# ModuleName: Dns, RequiredVersion: 1.3.1
# ModuleName: DnsResolver, RequiredVersion: 1.1.1
# ModuleName: ElasticSan, RequiredVersion: 1.2.1
# ModuleName: EventGrid, RequiredVersion: 2.2.0
# ModuleName: EventHub, RequiredVersion: 5.2.0
# ModuleName: FrontDoor, RequiredVersion: 1.12.0
# ModuleName: Functions, RequiredVersion: 4.2.0
# ModuleName: HDInsight, RequiredVersion: 6.3.1
# ModuleName: HealthcareApis, RequiredVersion: 2.1.0
# ModuleName: HealthDataAIServices, RequiredVersion: 1.0.0
# ModuleName: IotHub, RequiredVersion: 2.8.0
# ModuleName: KeyVault, RequiredVersion: 6.3.1
# ModuleName: Kusto, RequiredVersion: 2.4.0
# ModuleName: LoadTesting, RequiredVersion: 1.1.0
# ModuleName: LogicApp, RequiredVersion: 1.6.0
# ModuleName: MachineLearning, RequiredVersion: 1.2.0
# ModuleName: MachineLearningServices, RequiredVersion: 1.2.0
# ModuleName: Maintenance, RequiredVersion: 1.5.1
# ModuleName: ManagedServiceIdentity, RequiredVersion: 1.3.0
# ModuleName: ManagedServices, RequiredVersion: 3.1.0
# ModuleName: MarketplaceOrdering, RequiredVersion: 2.1.0
# ModuleName: Media, RequiredVersion: 1.2.0
# ModuleName: Migrate, RequiredVersion: 2.7.0
# ModuleName: Monitor, RequiredVersion: 6.0.1
# ModuleName: MySql, RequiredVersion: 1.3.0
# ModuleName: Network, RequiredVersion: 7.15.0
# ModuleName: NetworkCloud, RequiredVersion: 1.1.0
# ModuleName: Nginx, RequiredVersion: 1.2.0
# ModuleName: NotificationHubs, RequiredVersion: 1.2.0
# ModuleName: OperationalInsights, RequiredVersion: 3.3.0
# ModuleName: Oracle, RequiredVersion: 1.1.0
# ModuleName: PolicyInsights, RequiredVersion: 1.7.1
# ModuleName: PostgreSql, RequiredVersion: 1.2.0
# ModuleName: PowerBIEmbedded, RequiredVersion: 2.1.0
# ModuleName: PrivateDns, RequiredVersion: 1.2.0
# ModuleName: RecoveryServices, RequiredVersion: 7.5.1
# ModuleName: RedisCache, RequiredVersion: 1.11.0
# ModuleName: RedisEnterpriseCache, RequiredVersion: 1.4.1
# ModuleName: Relay, RequiredVersion: 2.1.0
# ModuleName: ResourceGraph, RequiredVersion: 1.2.0
# ModuleName: ResourceMover, RequiredVersion: 1.3.0
# ModuleName: Resources, RequiredVersion: 7.9.0
# ModuleName: Security, RequiredVersion: 1.8.0
# ModuleName: SecurityInsights, RequiredVersion: 3.2.0
# ModuleName: ServiceBus, RequiredVersion: 4.1.1
# ModuleName: ServiceFabric, RequiredVersion: 3.5.0
# ModuleName: SignalR, RequiredVersion: 2.1.0
# ModuleName: Sql, RequiredVersion: 6.0.2
# ModuleName: SqlVirtualMachine, RequiredVersion: 2.4.0
# ModuleName: StackHCI, RequiredVersion: 2.5.0
# ModuleName: StackHCIVM, RequiredVersion: 1.1.0
# ModuleName: Storage, RequiredVersion: 8.2.0
# ModuleName: StorageMover, RequiredVersion: 1.5.0
# ModuleName: StorageSync, RequiredVersion: 2.4.1
# ModuleName: StreamAnalytics, RequiredVersion: 2.1.0
# ModuleName: Support, RequiredVersion: 2.1.0
# ModuleName: Synapse, RequiredVersion: 3.1.2
# ModuleName: TrafficManager, RequiredVersion: 1.3.0
# ModuleName: Websites, RequiredVersion: 3.3.1
# ModuleName: Workloads, RequiredVersion: 1.0.0

# %%
df.head()
# Out:
#              module                 sub_module v_autorest     GA Status
# 0          Accounts                       None       None  False   None
# 1  ADDomainServices  ADDomainServices.Autorest         v3  False   None
# 2           Advisor           Advisor.Autorest         v3   True   None
# 3               Aks               Aks.Autorest         v3   True   None
# 4            AksArc            AksArc.Autorest         v4  False   None

# %%
n_modules = df['module'].nunique()
n_v3_sub_modules = df.loc[df['v_autorest'] == 'v3'].shape[0]
n_v3_modules = df.loc[df['v_autorest'] == 'v3']['module'].nunique()

print(f"Total number of modules are {n_modules}.")
print(f"Among them, total number of v3 modules are {n_v3_modules}.")
print(f"Within v3 modules, there are {n_v3_sub_modules} actual sub modules need to be upgraded.")
# Out:
# Total number of modules are 190.
# Among them, total number of v3 modules are 100.
# Within v3 modules, there are 106 actual sub modules need to be upgraded.

# %%
ga_modules = df.loc[df['GA'] == True]['module'].nunique()
v3_ga_modules = df.loc[(df['GA'] == True) & (df['v_autorest'] == 'v3')]['module'].nunique()
v3_ga_sub_modules = df.loc[(df['GA'] == True) & (df['v_autorest'] == 'v3')].shape[0]

print(f"There are total {v3_ga_modules} V3 GA modules, can be further devided into {v3_ga_sub_modules} V3 GA sub modules that should be upgraded first.")
# Out:
# There are total 45 V3 GA modules, can be further devided into 50 V3 GA sub modules that should be upgraded first.

# %%
n_v4_modules = df.loc[df['v_autorest'] == 'v4']['module'].nunique()
n_v4_sub_modules = df.loc[df['v_autorest'] == 'v4'].shape[0]
print(f"There are total {n_v4_modules} V4 modules, can be further devided into {n_v4_sub_modules} V4 sub modules.")
# Out:
# There are total 47 V4 modules, can be further devided into 54 V4 sub modules.

# %%
v3_nga_sub_modules = df.loc[(df['GA'] == False) & (df['v_autorest'] == 'v3')].shape[0]
print(f"There are total {v3_nga_sub_modules} v3 pre-GA modules")
# Out:
# There are total 56 v3 pre-GA modules

# %%
df.to_csv('modules_audit.csv', index=False)

# %% [markdown]
# ### Sort on autorest version and GA

# %%
v_autorest_order = {'v3': 0, 'v4': 1, 'none': 2}
df['v_autorest_sort'] = df['v_autorest'].map(v_autorest_order)
df_sorted = df.sort_values(by=['v_autorest_sort', 'GA'], ascending=[True, False])
df_sorted = df_sorted.drop(columns=['v_autorest_sort'])
df_sorted.to_csv('modules_audit_sorted.csv', index=False)
